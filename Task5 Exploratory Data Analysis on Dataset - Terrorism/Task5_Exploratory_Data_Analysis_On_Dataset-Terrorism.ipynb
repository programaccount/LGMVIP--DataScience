# %% [markdown]
# **LetsGrowMore Virtual Internship Program**
#
# Data Science Internship - LGMVIP JULY 2022
#
#
# ---
#
#
# **By: Arunjyoti Mukherjee**
#
# Linkedin: https://www.linkedin.com/in/arunjyoti-mukherjee-903823178/
#
# GitHub: https://github.com/programaccount
#
#
# ---
#
#
# **Intermediate Level Task1:**
#
# **Exploratory Data Analysis on Dataset - Terrorism.**
#
# **Dataset:**  https://bit.ly/2TK5Xn5

# %% [markdown]
# **Importing all the necessary required libraries**

# %%
#Importing all the necessary required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
from IPython.display import clear_output
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_csv("gdrive/My Drive/Colab Notebooks/Lets Grow More Internship Tasks/Dataset Task Files/globalterrorismdb_0718dist.csv",dtype = 'unicode',encoding='latin1')
df.head()
# Out:
#         eventid iyear imonth iday approxdate extended resolution country  \
# 0  197000000001  1970      7    2        NaN        0        NaN      58
# 1  197000000002  1970      0    0        NaN        0        NaN     130
# 2  197001000001  1970      1    0        NaN        0        NaN     160
# 3  197001000002  1970      1    0        NaN        0        NaN      78
# 4  197001000003  1970      1    0        NaN        0        NaN     101
#
#           country_txt region  ... addnotes scite1 scite2 scite3 dbsource  \
# 0  Dominican Republic      2  ...      NaN    NaN    NaN    NaN     PGIS
# 1              Mexico      1  ...      NaN    NaN    NaN    NaN     PGIS
# 2         Philippines      5  ...      NaN    NaN    NaN    NaN     PGIS
# 3              Greece      8  ...      NaN    NaN    NaN    NaN     PGIS
# 4               Japan      4  ...      NaN    NaN    NaN    NaN     PGIS
#
#   INT_LOG INT_IDEO INT_MISC INT_ANY related
# 0       0        0        0       0     NaN
# 1       0        1        1       1     NaN
# 2      -9       -9        1       1     NaN
# 3      -9       -9        1       1     NaN
# 4      -9       -9        1       1     NaN
#
# [5 rows x 135 columns]

# %%
df.tail()
# Out:
#              eventid iyear imonth iday approxdate extended resolution country  \
# 181686  201712310022  2017     12   31        NaN        0        NaN     182
# 181687  201712310029  2017     12   31        NaN        0        NaN     200
# 181688  201712310030  2017     12   31        NaN        0        NaN     160
# 181689  201712310031  2017     12   31        NaN        0        NaN      92
# 181690  201712310032  2017     12   31        NaN        0        NaN     160
#
#         country_txt region  ... addnotes  \
# 181686      Somalia     11  ...      NaN
# 181687        Syria     10  ...      NaN
# 181688  Philippines      5  ...      NaN
# 181689        India      6  ...      NaN
# 181690  Philippines      5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource INT_LOG INT_IDEO INT_MISC INT_ANY related
# 181686  START Primary Collection       0        0        0       0     NaN
# 181687  START Primary Collection      -9       -9        1       1     NaN
# 181688  START Primary Collection       0        0        0       0     NaN
# 181689  START Primary Collection      -9       -9        0      -9     NaN
# 181690  START Primary Collection      -9       -9        0      -9     NaN
#
# [5 rows x 135 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: object(135)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#              eventid   iyear  imonth    iday             approxdate extended  \
# count         181691  181691  181691  181691                   9239   181691
# unique        181691      47      13      32                   2244        2
# top     197000000001    2014       5      15  September 18-24, 2016        0
# freq               1   16903   16875    6500                    101   173452
#
#        resolution country country_txt  region  ...  \
# count        2220  181691      181691  181691  ...
# unique       1859     205         205      12  ...
# top      8/4/1998      95        Iraq      10  ...
# freq           18   24636       24636   50474  ...
#
#                                                  addnotes  \
# count                                               28289
# unique                                              15429
# top     Casualty numbers for this incident conflict ac...
# freq                                                 1607
#
#                                                    scite1  \
# count                                              115500
# unique                                              83988
# top     Committee on Government Operations United Stat...
# freq                                                  205
#
#                                                    scite2  \
# count                                               76933
# unique                                              62263
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  134
#
#                                                    scite3  \
# count                                               43516
# unique                                              36090
# top     Christopher Hewitt, "Political Violence and Te...
# freq                                                  139
#
#                         dbsource INT_LOG INT_IDEO INT_MISC INT_ANY  \
# count                     181691  181691   181691   181691  181691
# unique                        26       3        3        3       3
# top     START Primary Collection      -9       -9        0      -9
# freq                       78002   92527    92659   160467   83830
#
#                                                   related
# count                                               25038
# unique                                              14306
# top     201612010023, 201612010024, 201612010025, 2016...
# freq                                                   80
#
# [4 rows x 135 columns]

# %% [markdown]
# **Finding the Null Values**

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# **Plotting the Same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['country_txt'].value_counts()[:5].index,df['country_txt'].value_counts()[:5].values)
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **IRAQ is the most affected Country with Terrorist Attacks**

# %% [markdown]
# **The Top 5 Regions with most Terrorist Attacks**

# %%
print(df['region_txt'].value_counts().head(5))
# Out:
# Middle East & North Africa    50474
# South Asia                    44974
# South America                 18978
# Sub-Saharan Africa            17550
# Western Europe                16639
# Name: region_txt, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['region_txt'].value_counts()[:5].index,df['region_txt'].value_counts()[:5].values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Middle East and North Africa is the region with most Terrorist Attacks Followed by South Asia**

# %% [markdown]
# **Top 5 Cities with most Terrorist Attacks**

# %%
print(df['city'].value_counts().head(5))
# Out:
# Unknown    9775
# Baghdad    7589
# Karachi    2652
# Lima       2359
# Mosul      2265
# Name: city, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['city'].value_counts()[:5].index,df['city'].value_counts()[:5].values)
plt.xlabel('city')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **BAGHDAD is the City with most Terrorist Attacks Since First One is Unknown**

# %% [markdown]
# **Top 5 States with Most Terrorist Attacks**

# %%
print(df['provstate'].value_counts().head(5))
# Out:
# Baghdad             7645
# Northern Ireland    4498
# Unknown             4290
# Balochistan         3710
# Saladin             3411
# Name: provstate, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['provstate'].value_counts()[:5].index,df['provstate'].value_counts()[:5].values)
plt.xlabel('state')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **BAGHDAD is the State with Most Terrorist Attacks**

# %% [markdown]
# **Years with Most and Least Terrorist Attacks**

# %%
print(df['iyear'].value_counts())
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: iyear, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['iyear'].value_counts().index,df['iyear'].value_counts().values)
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **2014 is the Year with Most and 1971 is the Year with Least Terrorist Activities**

# %% [markdown]
# **Top 5 Most Active Terrorist Groups**

# %%
print(df['gname'].value_counts().head(5))
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Name: gname, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['gname'].value_counts()[:5].index,df['gname'].value_counts()[:5].values)
plt.xlabel('Terrorist Group')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **TALIBAN is the Most Active Terrorist Group Since First One is Unknown**

# %% [markdown]
# **Top 5 Months with Most Terrorist Attacks**

# %%
print(df['imonth'].value_counts().head(5))
# Out:
# 5     16875
# 7     16268
# 8     15800
# 10    15563
# 6     15359
# Name: imonth, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['imonth'].value_counts()[:5].index,df['imonth'].value_counts()[:5].values)
plt.xlabel('Month')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Most Terrorist Attacks Took Place in the Month of May**

# %% [markdown]
# **Top 5 Method of Terrorist Attacks**

# %%
print(df['attacktype1_txt'].value_counts().head(5))
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: attacktype1_txt, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['attacktype1_txt'].value_counts()[:5].index,df['attacktype1_txt'].value_counts()[:5].values)
plt.xlabel('Attack Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **BOMBING/EXPLOSION is the Most Common Method Used in Terrorist Attacks**

# %% [markdown]
# **Top 5 Targets of Terrorist Attacks**

# %%
print(df['targtype1_txt'].value_counts().head(5))
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: targtype1_txt, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['targtype1_txt'].value_counts()[:5].index,df['targtype1_txt'].value_counts()[:5].values)
plt.xlabel('Affected Targets')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Private Citizens and Property are Most Affected by Terrorist Attacks Followed by Military,Police,General Government and Business**

# %% [markdown]
# **Top 5 Weapons Used for Terrorist Attacks**

# %%
print(df['weaptype1_txt'].value_counts().head(5))
# Out:
# Explosives    92426
# Firearms      58524
# Unknown       15157
# Incendiary    11135
# Melee          3655
# Name: weaptype1_txt, dtype: int64

# %% [markdown]
# **Plotting the same in a Bar Graph**

# %%
plt.figure(figsize = (10,5))
sns.barplot(df['weaptype1_txt'].value_counts()[:5].index,df['weaptype1_txt'].value_counts()[:5].values)
plt.xlabel('Weapons Used')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Explosives are Mostly used as Weapons for Terrorist Attacks**

# %%
df['success'].value_counts()
# Out:
# 1    161632
# 0     20059
# Name: success, dtype: int64

# %% [markdown]
# **Terrorists are Successful 161632 Times and Failed 20059 in Conducting Terrorist Attacks**

# %%
df['suicide'].value_counts()
# Out:
# 0    175058
# 1      6633
# Name: suicide, dtype: int64

# %% [markdown]
# **6633 People Committed Suicide During the Attacks**

# %% [markdown]
# **CONCLUSION:**
#
# 1. Most Affected Country - IRAQ.
#
# 2. Most Affected State - BAGHDAD
#
# 3. Most Affected City - BAGHDAD
#
# 4. Most Affected Region - MIDDLE EAST and NORTH AFRICA
#
# 5. Most Terrific Year - 2014.
#
# 6. Year with least Terrorist Activities - 1971
#
# 7. Most Commonly Used Attack Type - Bombing / Explosion.
#
# 8. Weapon used Most Number of Times - Explosives
#
# 9. Most Active Terrorist Group With Maximum Number of Attacks - TALIBAN
#
# 10. Affected Targets of Terrorist Attacks - Private Citizens and Property are Most Affected by Terrorist Attacks Followed by Military, Police, General Government and Business
#
# 11. Month with Most Attacks - MAY
#
#   The Hotzonne of Terrorism: IRAQ
